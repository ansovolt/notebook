# %%
from pyimagesearch.transform import four_point_transform
from pyimagesearch import imutils
from skimage.filters import threshold_adaptive
import numpy as np
import argparse
import cv2
import matplotlib.pyplot as plt
from PIL import Image
# %matplotlib inline

# %%
image = cv2.imread('document-scanner/images/receipt.jpg')
#image = cv2.imread('document-scanner/images/braums-4.jpg')
#image = cv2.imread('document-scanner/images/1-original-receipt-view.png')
#ratio = image.shape[0] / 500.0
ratio = image.shape[0] / 650.0
print ("ratio %s" % ratio)
orig = image.copy()
image = imutils.resize(image, height = 650)
# Out:
# ratio 5.021538461538461

# %%
gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
gray = cv2.GaussianBlur(gray, (5, 5), 0)
edged = cv2.Canny(gray, 75, 200)

# %%
plt.imshow(image)
plt.show()
plt.imshow(edged, cmap='gray')
plt.show()

# %%
_, cnts, hierarchy = cv2.findContours(edged.copy(), cv2.RETR_LIST, cv2.CHAIN_APPROX_SIMPLE)
cnts = sorted(cnts, key = cv2.contourArea, reverse = True)[:10]
screenCnt = None
i = 0
maxp = 0
selp = 0
selc = None
for c in cnts:
	#print ("countur %d" % i)
	#i = i + 1
	# approximate the contour
	peri = cv2.arcLength(c, True)
	approx = cv2.approxPolyDP(c, 0.02 * peri, True)
	print ("peri is %s" % peri)
	if selp < peri:
		selp = peri
		selc = approx
		screenCnt = approx
	#print ("approx is %s" % approx) 

    
	if len(approx) == 4:
		screenCnt = approx
		break
print("selp %s" % selp)
# Out:
# peri is 1156.9188276529312
# selp 1156.9188276529312

# %%
cv2.drawContours(image, [screenCnt], -1, (0, 255, 0), 2)
#cv2.drawContours(image, cnts, -1, (0, 255, 0), 2)
#cv2.drawContours(image, [selc], 0, (0, 255, 0), 2)
# Out:
# array([[[31, 41, 57],
#         [34, 45, 59],
#         [35, 48, 62],
#         ...,
#         [56, 69, 82],
#         [54, 68, 80],
#         [57, 70, 82]],
#
#        [[37, 47, 63],
#         [35, 46, 60],
#         [38, 49, 63],
#         ...,
#         [60, 73, 86],
#         [59, 72, 84],
#         [51, 64, 76]],
#
#        [[35, 46, 62],
#         [39, 50, 64],
#         [35, 48, 62],
#         ...,
#         [56, 67, 82],
#         [64, 76, 89],
#         [51, 63, 77]],
#
#        ...,
#        [[16, 28, 38],
#         [20, 30, 40],
#         [20, 30, 40],
#         ...,
#         [75, 83, 96],
#         [70, 78, 91],
#         [63, 72, 85]],
#
#        [[19, 31, 41],
#         [20, 30, 41],
#         [23, 32, 44],
#         ...,
#         [69, 77, 90],
#         [71, 79, 92],
#         [61, 67, 83]],
#
#        [[20, 33, 44],
#         [26, 36, 49],
#         [27, 36, 50],
#         ...,
#         [78, 86, 98],
#         [78, 84, 99],
#         [62, 66, 85]]], dtype=uint8)

# %%
plt.imshow(image)
plt.show()

# %%
warped = four_point_transform(orig, screenCnt.reshape(4, 2) * ratio)
warped = cv2.cvtColor(warped, cv2.COLOR_BGR2GRAY)
warped = threshold_adaptive(warped, 251, offset = 10)
warped = warped.astype("uint8") * 255

# %%
plt.imshow(imutils.resize(warped, height = 650), cmap='gray')
plt.show()

# %%
fig = plt.figure()
a=fig.add_subplot(1,2,1)
imgplot1 = plt.imshow(imutils.resize(orig, height = 650))
a.set_title('Before')
a=fig.add_subplot(1,2,2)
imgplot2 = plt.imshow(imutils.resize(warped, height = 650), cmap='gray')
a.set_title('After')
plt.show()

# %%
im = Image.fromarray(imutils.resize(warped, height = 650, width = 650))
im.save("final_file.jpeg")

# %%
# %%bash
# ocropus-nlbin -n your_file.jpeg -o img_out
# Out:
# INFO:  # your_file.jpeg
# INFO:  === your_file.jpeg 1
# INFO:  flattening
# INFO:  estimating skew angle
# INFO:  estimating thresholds
# INFO:  rescaling
# INFO:  your_file.jpeg lo-hi (0.24 1.24) angle -2.0
# INFO:  writing

# %%
# %%bash
# ocropus-gpageseg -n --maxcolseps 0 --minscale 8.0 img_out/0001.bin.png
# Out:
# INFO:
# INFO:  ########## /usr/local/bin/ocropus-gpageseg -n --maxcolseps 0 --minscale
# INFO:
# INFO:  img_out/0001.bin.png
# INFO:  scale 12.000000
# INFO:  computing segmentation
# INFO:  computing column separators
# INFO:  computing lines
# INFO:  propagating labels
# INFO:  spreading labels
# INFO:  number of lines 35
# INFO:  finding reading order
# INFO:  writing lines
# INFO:      34  img_out/0001.bin.png 12.0 35

# %%
# %%bash
# ocropus-rpred -m en-default.pyrnn.gz img_out/0001/*.png
# Out:
# INFO:
# INFO:  ########## /usr/local/bin/ocropus-rpred -m en-default.pyrnn.gz img_out/
# INFO:
# INFO:  #inputs: 35
# # loading object ././en-default.pyrnn.gz
# INFO:  img_out/0001/010001.bin.png:
# INFO:  img_out/0001/010002.bin.png:D
# INFO:  img_out/0001/010003.bin.png:iLE FDODS MRRET - VESTPORT,CT 06880
# INFO:  img_out/0001/010004.bin.png:A9 POST RD ST - (203) 227-68S8
# INFO:  img_out/0001/010005.bin.png:y .
# INFO:  img_out/0001/010006.bin.png::- --
# INFO:  img_out/0001/010007.bin.png:345 BACON LS NP 4 99 F
# INFO:  img_out/0001/010008.bin.png:365 BACON LS NP 4.99 F -'
# INFO:  img_out/0001/010009.bin.png:'.
# INFO:  img_out/0001/01000a.bin.png:365 BRCDN LS P 4.99 F
# INFO:  img_out/0001/01000b.bin.png:365 BACON LS NP 4 99 F w -,
# INFO:  img_out/0001/01000c.bin.png:BRDTH ChIC P 2 19 F
# INFO:  img_out/0001/01000d.bin.png:FLOUR RLMOND NP A1.99 F
# INFO:  img_out/0001/01000e.bin.png:
# INFO:  img_out/0001/01000f.bin.png:CHRN BRST BNLSS Sk P 18 80 F
# INFO:  img_out/0001/010010.bin.png:HERVY CRERN NP 3 39 F - f 1
# INFO:  INFO:  img_out/0001/010012.bin.png:auIce coF casHEV c P fs ss F .z
# INFO:  img_out/0001/010013.bin.png:nacs rI OGasIc sP '14,49 F ,'
# INFO:  img_out/0001/010014.bin.png:HNY RLMOND uTTER P 9 99 s
# INFO:  img_out/0001/010015.bin.png:awas TRx 00 BRL 101,32
# INFO:  img_out/0001/010016.bin.png:*., ' -7-
# INFO:  img_out/0001/010017.bin.png:.z
# INFO:  img_out/0001/010018.bin.png:.9-
# INFO:  img_out/0001/010019.bin.png:-> A
# INFO:  img_out/0001/01001a.bin.png:,:
# INFO:  img_out/0001/01001b.bin.png:BRLSND REDUCT NP 6.49 F , .
# INFO:  img_out/0001/01001c.bin.png:- '
# INFO:  img_out/0001/01001d.bin.png:' .2
# INFO:  img_out/0001/01001e.bin.png:' .
# INFO:  img_out/0001/01001f.bin.png:AA'
# INFO:  img_out/0001/010020.bin.png:, -
# INFO:  img_out/0001/010021.bin.png:'
# INFO:  img_out/0001/010022.bin.png:-,
# INFO:  img_out/0001/010023.bin.png:.
# Traceback (most recent call last):
#   File "/usr/local/bin/ocropus-rpred", line 261, in safe_process1
#     return process1(arg)
#   File "/usr/local/bin/ocropus-rpred", line 217, in process1
#     ocrolib.write_text(base+".txt",pred)
#   File "/usr/local/lib/python2.7/dist-packages/ocrolib/common.py", line 172, in write_text
#     if not nonl and text[-1]!='\n':
# IndexError: string index out of range
# Traceback (most recent call last):
#   File "/usr/local/bin/ocropus-rpred", line 261, in safe_process1
#     return process1(arg)
#   File "/usr/local/bin/ocropus-rpred", line 217, in process1
#     ocrolib.write_text(base+".txt",pred)
#   File "/usr/local/lib/python2.7/dist-packages/ocrolib/common.py", line 172, in write_text
#     if not nonl and text[-1]!='\n':
# IndexError: string index out of range
# Traceback (most recent call last):
#   File "/usr/local/bin/ocropus-rpred", line 261, in safe_process1
#     return process1(arg)
#   File "/usr/local/bin/ocropus-rpred", line 216, in process1
#     print_info(fname+":"+pred)
#   File "/usr/local/bin/ocropus-rpred", line 68, in print_info
#     print("INFO: ", *objs, file=sys.stdout)
# UnicodeEncodeError: 'ascii' codec can't encode character u'\xdf' in position 47: ordinal not in range(128)

# %%
# %%bash
# cat img_out/????/??????.txt > ocr.txt
